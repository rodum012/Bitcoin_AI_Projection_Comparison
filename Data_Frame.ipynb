# %%
import time
import datetime
import pandas as pd
import yfinance as yf
from yahoo_fin.stock_info import get_data
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Bitcoin

# %%
BTC_df = get_data("BTC-USD", start_date="6/30/2019", end_date="06/30/2022", index_as_date = True, interval="1d")
Dodge_df = get_data("DOGE-USD", start_date="6/30/2019", end_date="06/30/2022", index_as_date = True, interval="1d")
Eth_df = get_data("ETH-USD", start_date="6/30/2019", end_date="06/30/2022", index_as_date = True, interval="1d")
Ada_df = get_data("ADA-USD", start_date="6/30/2019", end_date="06/30/2022", index_as_date = True, interval="1d")
Xrp_df = get_data("XRP-USD", start_date="6/30/2019", end_date="06/30/2022", index_as_date = True, interval="1d")

Top5 = [BTC_df,Dodge_df,Eth_df,Ada_df,Xrp_df]
Total_df = pd.concat(Top5, axis=1)

Total_df.head()
# Out:
#                     open          high           low         close  \
# 2019-06-30  11931.991211  12178.383789  10799.008789  10817.155273
# 2019-07-01  10796.930664  11206.439453  10089.314453  10583.134766
# 2019-07-02  10588.683594  10912.188477   9737.884766  10801.677734
# 2019-07-03  10818.156250  11968.078125  10818.156250  11961.269531
# 2019-07-04  11972.718750  12006.075195  11166.569336  11215.437500
#
#                 adjclose       volume   ticker      open      high       low  \
# 2019-06-30  10817.155273  27256473494  BTC-USD  0.003418  0.003446  0.003247
# 2019-07-01  10583.134766  29378589324  BTC-USD  0.003250  0.003325  0.003093
# 2019-07-02  10801.677734  31015895223  BTC-USD  0.003237  0.003360  0.003080
# 2019-07-03  11961.269531  30796494294  BTC-USD  0.003207  0.003336  0.003172
# 2019-07-04  11215.437500  25920294033  BTC-USD  0.003314  0.003357  0.003131
#
#             ...  adjclose     volume   ticker      open      high       low  \
# 2019-06-30  ...  0.082098  161855807  ADA-USD  0.429180  0.429180  0.396411
# 2019-07-01  ...  0.083822  168654991  ADA-USD  0.395900  0.417618  0.389673
# 2019-07-02  ...  0.081077  180980795  ADA-USD  0.406414  0.409737  0.384477
# 2019-07-03  ...  0.082998  154492407  ADA-USD  0.400178  0.409239  0.396724
# 2019-07-04  ...  0.077774  142713205  ADA-USD  0.408316  0.408655  0.387974
#
#                close  adjclose      volume   ticker
# 2019-06-30  0.396411  0.396411  1570726856  XRP-USD
# 2019-07-01  0.406862  0.406862  1783852226  XRP-USD
# 2019-07-02  0.400204  0.400204  1676193189  XRP-USD
# 2019-07-03  0.408532  0.408532  1436716899  XRP-USD
# 2019-07-04  0.388719  0.388719  1385563454  XRP-USD
#
# [5 rows x 35 columns]
